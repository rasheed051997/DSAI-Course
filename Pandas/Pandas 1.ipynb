# %% [markdown]
# # Pandas
#
# - Pandas is a fast,powerful and easy to use open source data analysis and manipulation package,built on top of Python developed by Wes McKinney
#
# - pandas and numpy will be used in your entire career as Software/AI/ML/DS professional
#
# - When working with tabular data, such as data stored in spreadsheets or databases, pandas is the right tool for us.
#
# - pandas will help us to explore, clean and process your data.
#
# - In pandas, a data table is called a DataFrame.Dataframe is a collection of rows and columns
#
# - if we are reading only one column or one row from a dataframe then its type is called as series

# %%
import pandas as pd

# %%
df=pd.read_csv('D:\DSAICourse\Pandas\DataSet\ex1.csv')  

#variable assigned for read .csv file using pandas variable and  
#use 'r' in pd.read_csv(r,'directory') for raw data for read directory and not as string when escape sequence characters came...

# %%
df 
# output type is a data frame 
# left most no.s are pandas dataframe indexes
#when reading it automatically use first row as heading
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(2) #Return the first `n` rows.
# Out:
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world

# %%
df.tail(2)  #Return the last `n` rows.
# Out:
#    a   b   c   d message
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_table(r'D:\DSAICourse\Pandas\DataSet\test.tsv')  
# tsv files read correctly by  read_table()
# if the file is in our workbook directory so you can read direct with filename
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.
#           test    test  test.1  test.2  test.3
# suresh  suresh  suresh  suresh  suresh  suresh
# kumar    kumar   kumar   kumar   kumar   kumar

# %%
pd.read_csv(r'D:\DSAICourse\Pandas\DataSet\test.tsv')   
#you can read tsv file using read_csv() , but it prints the tab (\t) characters
# Out:
#                     test\t test\ttest\ttest\ttest
# 0  suresh\tsuresh\tsuresh\tsuresh\tsuresh\tsuresh
# 1        kumar\tkumar\tkumar\tkumar\tkumar\tkumar

# %%
#so use seperate command to overcome,  sep='\t'
pd.read_csv(r'D:\DSAICourse\Pandas\DataSet\test.tsv',sep='\t')
# Out:
#           test    test  test.1  test.2  test.3
# suresh  suresh  suresh  suresh  suresh  suresh
# kumar    kumar   kumar   kumar   kumar   kumar

# %%
df=pd.read_csv('D:\DSAICourse\Pandas\DataSet\ex1.csv',header=None) 
#header=None  it defines header as pandas index
#otherwise by default when reading it automatically use first row as heading 
df
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
df=pd.read_csv('D:\DSAICourse\Pandas\DataSet\ex1.csv',names=['Mark1','Mark2','Mark3','Mark4','Message']) 
#b using names=['name1'] you can define other header as your wish
df
# Out:
#   Mark1 Mark2 Mark3 Mark4  Message
# 0     a     b     c     d  message
# 1     1     2     3     4    hello
# 2     5     6     7     8    world
# 3     9    10    11    12      foo

# %%
df=pd.read_csv('D:\DSAICourse\Pandas\DataSet\ex1.csv',names=['Mark1','Mark2','Mark3','Mark4','name','Message']) 
# if we given exra column name it show as a null column , so it cant show an value in column default show as 'NaN'
df
# Out:
#   Mark1 Mark2 Mark3 Mark4     name  Message
# 0     a     b     c     d  message      NaN
# 1     1     2     3     4    hello      NaN
# 2     5     6     7     8    world      NaN
# 3     9    10    11    12      foo      NaN

# %%
df=pd.read_csv('D:\DSAICourse\Pandas\DataSet\ex1.csv',names=['Mark1','Mark2','Mark3','Message']) 
# if one column name is less first column has no header name and change in place of index
df
# Out:
#   Mark1 Mark2 Mark3  Message
# a     b     c     d  message
# 1     2     3     4    hello
# 5     6     7     8    world
# 9    10    11    12      foo

# %%
df=pd.read_csv('D:\DSAICourse\Pandas\DataSet\ex1.csv')
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
dfs=pd.read_csv('D:\DSAICourse\Pandas\DataSet\ex1.csv',skiprows=[2])
#we can use skiprows=[] for block unwanted rows, rows selected by 0,1,.....
dfs
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  9  10  11  12     foo

# %%
pd.isnull(df)
# it shows True  when null detects
# Out:
#        a      b      c      d  message
# 0  False  False  False  False    False
# 1  False  False  False  False    False
# 2  False  False  False  False    False

# %%
# column renaming
df.rename(columns={'message':'msg','a':'A'})
# actual column not change. df   not change
#check df
#df
# Out:
#    A   b   c   d    msg
# 0  1   2   3   4  hello
# 1  5   6   7   8  world
# 2  9  10  11  12    foo

# %%
df1=df.rename(columns={'message':'msg1','b':'B'})
df1
# by assign change to a variable
# Out:
#    a   B   c   d   msg1
# 0  1   2   3   4  hello
# 1  5   6   7   8  world
# 2  9  10  11  12    foo

# %%
# Reading excel files
ex=pd.read_excel('D:\DSAICourse\Pandas\DataSet\SampleExcel.xlsx')
ex
# Out:
#     OrderDate   Region       Rep     Item  Units  Unit Cost    Total
# 0  2019-01-06     East     Jones   Pencil     95       1.99   189.05
# 1  2019-01-23  Central    Kivell   Binder     50      19.99   999.50
# 2  2019-02-09  Central   Jardine   Pencil     36       4.99   179.64
# 3  2019-02-26  Central      Gill      Pen     27      19.99   539.73
# 4  2019-03-15     West   Sorvino   Pencil     56       2.99   167.44
# 5  2019-04-01     East     Jones   Binder     60       4.99   299.40
# 6  2019-04-18  Central   Andrews   Pencil     75       1.99   149.25
# 7  2019-05-05  Central   Jardine   Pencil     90       4.99   449.10
# 8  2019-05-22     West  Thompson   Pencil     32       1.99    63.68
# 9  2019-06-08     East     Jones   Binder     60       8.99   539.40
# 10 2019-06-25  Central    Morgan   Pencil     90       4.99   449.10
# 11 2019-07-12     East    Howard   Binder     29       1.99    57.71
# 12 2019-07-29     East    Parent   Binder     81      19.99  1619.19
# ...

# %%
ex.head() #deafult value ttake as 5, print 5 rows
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0 2019-01-06     East    Jones  Pencil     95       1.99  189.05
# 1 2019-01-23  Central   Kivell  Binder     50      19.99  999.50
# 2 2019-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 3 2019-02-26  Central     Gill     Pen     27      19.99  539.73
# 4 2019-03-15     West  Sorvino  Pencil     56       2.99  167.44

# %%
ex.head(10)
# Out:
#    OrderDate   Region       Rep    Item  Units  Unit Cost   Total
# 0 2019-01-06     East     Jones  Pencil     95       1.99  189.05
# 1 2019-01-23  Central    Kivell  Binder     50      19.99  999.50
# 2 2019-02-09  Central   Jardine  Pencil     36       4.99  179.64
# 3 2019-02-26  Central      Gill     Pen     27      19.99  539.73
# 4 2019-03-15     West   Sorvino  Pencil     56       2.99  167.44
# 5 2019-04-01     East     Jones  Binder     60       4.99  299.40
# 6 2019-04-18  Central   Andrews  Pencil     75       1.99  149.25
# 7 2019-05-05  Central   Jardine  Pencil     90       4.99  449.10
# 8 2019-05-22     West  Thompson  Pencil     32       1.99   63.68
# 9 2019-06-08     East     Jones  Binder     60       8.99  539.40

# %%
ex.tail()
#deafult value ttake as 5, print 5 rows
# Out:
#     OrderDate   Region       Rep    Item  Units  Unit Cost    Total
# 38 2020-10-14     West  Thompson  Binder     57      19.99  1139.43
# 39 2020-10-31  Central   Andrews  Pencil     14       1.29    18.06
# 40 2020-11-17  Central   Jardine  Binder     11       4.99    54.89
# 41 2020-12-04  Central   Jardine  Binder     94      19.99  1879.06
# 42 2020-12-21  Central   Andrews  Binder     28       4.99   139.72

# %%
ex.tail(7)
# Out:
#     OrderDate   Region       Rep    Item  Units  Unit Cost    Total
# 36 2020-09-10  Central      Gill  Pencil      7       1.29     9.03
# 37 2020-09-27     West   Sorvino     Pen     76       1.99   151.24
# 38 2020-10-14     West  Thompson  Binder     57      19.99  1139.43
# 39 2020-10-31  Central   Andrews  Pencil     14       1.29    18.06
# 40 2020-11-17  Central   Jardine  Binder     11       4.99    54.89
# 41 2020-12-04  Central   Jardine  Binder     94      19.99  1879.06
# 42 2020-12-21  Central   Andrews  Binder     28       4.99   139.72

# %%
# Read other sheets in excel

ex1=pd.read_excel('D:\DSAICourse\Pandas\DataSet\SampleExcel.xlsx',sheet_name='Sheet2')
ex1
# Out:
#   2019-01-23 00:00:00  Central   Kivell  Binder
# 0          2019-02-09  Central  Jardine  Pencil
# 1          2019-02-26  Central     Gill     Pen
# 2          2019-03-15     West  Sorvino  Pencil
# 3          2019-04-01     East    Jones  Binder
# 4          2019-04-18  Central  Andrews  Pencil

# %%
# Read other sheets in excel and give heading

ex2=pd.read_excel('D:\DSAICourse\Pandas\DataSet\SampleExcel.xlsx',sheet_name='Sheet2',names=['Date','Location','Name','Thing'])
ex2
# Out:
#         Date Location     Name   Thing
# 0 2019-02-09  Central  Jardine  Pencil
# 1 2019-02-26  Central     Gill     Pen
# 2 2019-03-15     West  Sorvino  Pencil
# 3 2019-04-01     East    Jones  Binder
# 4 2019-04-18  Central  Andrews  Pencil

# %%
df4=pd.read_csv('https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv',sep=';')
df4
# use seperate for when reading online because seperated by characters
# Out:
#        age            job   marital            education  default  housing  \
# 0       56      housemaid   married             basic.4y       no       no
# 1       57       services   married          high.school  unknown       no
# 2       37       services   married          high.school       no      yes
# 3       40         admin.   married             basic.6y       no       no
# 4       56       services   married          high.school       no       no
# 5       45       services   married             basic.9y  unknown       no
# 6       59         admin.   married  professional.course       no       no
# 7       41    blue-collar   married              unknown  unknown       no
# 8       24     technician    single  professional.course       no      yes
# 9       25       services    single          high.school       no      yes
# 10      41    blue-collar   married              unknown  unknown       no
# ...

# %% [markdown]
# ##### 1 read data into data form from below url
# - https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv
#
# - 2 print first 5 rows
# - 3 print last 2 rows
# - 4 change some column names
# - 5 select a column and print its type
# - 6 print datatype of all columns in dataset
# - 7 check if any data is null
# - 8 skip random rows like 20,21 and 45

# %%
#1 read data into data form from below url
#https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv

qs=pd.read_csv('https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv',sep=';')
qs
# Out:
#        age            job   marital            education  default  housing  \
# 0       56      housemaid   married             basic.4y       no       no
# 1       57       services   married          high.school  unknown       no
# 2       37       services   married          high.school       no      yes
# 3       40         admin.   married             basic.6y       no       no
# 4       56       services   married          high.school       no       no
# 5       45       services   married             basic.9y  unknown       no
# 6       59         admin.   married  professional.course       no       no
# 7       41    blue-collar   married              unknown  unknown       no
# 8       24     technician    single  professional.course       no      yes
# 9       25       services    single          high.school       no      yes
# 10      41    blue-collar   married              unknown  unknown       no
# ...

# %%
#2 print first 5 rows

qs.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
#3 print last 2 rows

qs.tail(2)
# Out:
#        age         job  marital            education default housing loan  \
# 41186   44  technician  married  professional.course      no      no   no
# 41187   74     retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 41186  cellular   nov         fri  ...         1    999         0
# 41187  cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [2 rows x 21 columns]

# %%
# 4 change some column names

sml=qs.head(50)
sml.rename(columns={'education':'profession','housing':'house','contact':'phone'})
# Out:
#     age            job   marital           profession  default    house  \
# 0    56      housemaid   married             basic.4y       no       no
# 1    57       services   married          high.school  unknown       no
# 2    37       services   married          high.school       no      yes
# 3    40         admin.   married             basic.6y       no       no
# 4    56       services   married          high.school       no       no
# 5    45       services   married             basic.9y  unknown       no
# 6    59         admin.   married  professional.course       no       no
# 7    41    blue-collar   married              unknown  unknown       no
# 8    24     technician    single  professional.course       no      yes
# 9    25       services    single          high.school       no      yes
# 10   41    blue-collar   married              unknown  unknown       no
# 11   25       services    single          high.school       no      yes
# ...

# %%
# 5 select a column and print its type

print(type(qs['job']),"\n",type(qs['pdays']))


print(qs['job'].head(2),"\n",qs['pdays'].head(2))

print(qs['pdays'].dtype)
# Out:
# <class 'pandas.core.series.Series'>
#  <class 'pandas.core.series.Series'>
# 0    housemaid
# 1     services
# Name: job, dtype: object
#  0    999
# 1    999
# Name: pdays, dtype: int64
# int64

# %%
# 6 print datatype of all columns


print(type(qs))
print(qs.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
# 7 check if any data is null


pd.isnull(qs)
# Out:
#          age    job  marital  education  default  housing   loan  contact  \
# 0      False  False    False      False    False    False  False    False
# 1      False  False    False      False    False    False  False    False
# 2      False  False    False      False    False    False  False    False
# 3      False  False    False      False    False    False  False    False
# 4      False  False    False      False    False    False  False    False
# 5      False  False    False      False    False    False  False    False
# 6      False  False    False      False    False    False  False    False
# 7      False  False    False      False    False    False  False    False
# 8      False  False    False      False    False    False  False    False
# 9      False  False    False      False    False    False  False    False
# 10     False  False    False      False    False    False  False    False
# 11     False  False    False      False    False    False  False    False
# ...

# %%
# 8 skip random rows like 20,21 and 45

sk=pd.read_csv('https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv',sep=';',skiprows=[20,21,45])
sk
# Out:
#        age            job   marital            education  default  housing  \
# 0       56      housemaid   married             basic.4y       no       no
# 1       57       services   married          high.school  unknown       no
# 2       37       services   married          high.school       no      yes
# 3       40         admin.   married             basic.6y       no       no
# 4       56       services   married          high.school       no       no
# 5       45       services   married             basic.9y  unknown       no
# 6       59         admin.   married  professional.course       no       no
# 7       41    blue-collar   married              unknown  unknown       no
# 8       24     technician    single  professional.course       no      yes
# 9       25       services    single          high.school       no      yes
# 10      41    blue-collar   married              unknown  unknown       no
# ...

# %% [markdown]
# # pandas class 2

# %%
dfss=pd.read_csv('D:\DSAICourse\Pandas\DataSet\csv_mindex.csv')
dfss
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %%
# heirarchical indexing
#repeated values show as seperated.. keys   as our own index
dfss1=pd.read_csv('D:\DSAICourse\Pandas\DataSet\csv_mindex.csv',index_col=['key1','key2'])
dfss1
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16
