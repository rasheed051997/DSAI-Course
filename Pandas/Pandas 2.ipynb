# %% [markdown]
# # Pandas Class 2

# %%
import pandas as pd

# %%
#reading from html files
url="https://www.basketball-reference.com/leagues/NBA_2015_totals.html"
# also use     hh=read_html(url)
hh=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
hh
# Out:
# [      Rk                 Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
#  0      1             Quincy Acy   PF   24  NYK  68  22  1287  152   331  ...
#  1      2           Jordan Adams   SG   20  MEM  30   0   248   35    86  ...
#  2      3           Steven Adams    C   21  OKC  70  67  1771  217   399  ...
#  3      4            Jeff Adrien   PF   28  MIN  17   0   215   19    44  ...
#  4      5          Arron Afflalo   SG   29  TOT  78  72  2502  375   884  ...
#  5      5          Arron Afflalo   SG   29  DEN  53  53  1750  281   657  ...
#  6      5          Arron Afflalo   SG   29  POR  25  19   752   94   227  ...
#  7      6          Alexis Ajinça    C   26  NOP  68   8   957  181   329  ...
#  8      7         Furkan Aldemir   PF   23  PHI  41   9   540   40    78  ...
#  9      8           Cole Aldrich    C   26  NYK  61  16   976  144   301  ...
#  10     9      LaMarcus Aldridge   PF   29  POR  71  71  2512  659  1415  ...
# ...

# %%
hh[0]   #read in a clear format of dataframe or datasets
# Out:
#       Rk                 Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0      1             Quincy Acy   PF   24  NYK  68  22  1287  152   331  ...
# 1      2           Jordan Adams   SG   20  MEM  30   0   248   35    86  ...
# 2      3           Steven Adams    C   21  OKC  70  67  1771  217   399  ...
# 3      4            Jeff Adrien   PF   28  MIN  17   0   215   19    44  ...
# 4      5          Arron Afflalo   SG   29  TOT  78  72  2502  375   884  ...
# 5      5          Arron Afflalo   SG   29  DEN  53  53  1750  281   657  ...
# 6      5          Arron Afflalo   SG   29  POR  25  19   752   94   227  ...
# 7      6          Alexis Ajinça    C   26  NOP  68   8   957  181   329  ...
# 8      7         Furkan Aldemir   PF   23  PHI  41   9   540   40    78  ...
# 9      8           Cole Aldrich    C   26  NYK  61  16   976  144   301  ...
# 10     9      LaMarcus Aldridge   PF   29  POR  71  71  2512  659  1415  ...
# ...

# %%
hh[0].head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
hh1=hh[0]  #assign clear formatted data to a variable
hh1.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
hh1['MP'].head()  # read a column
# Out:
# 0    1287
# 1     248
# 2    1771
# 3     215
# 4    2502
# Name: MP, dtype: object

# %%
hh1['Pos'.'Age','TM']  #we cant read multiple columns directly
# Out:
#   File "<ipython-input-25-d70eb31a8c5b>", line 1
#     hh1['Pos'.'Age','TM']  #we cant read multiple columns directly
#                   ^
# SyntaxError: invalid syntax

# %%
hh2=hh1[['Player','Pos','Age','Tm']]   #read as list for multiple needed columns
hh2.head()
# Out:
#           Player Pos Age   Tm
# 0     Quincy Acy  PF  24  NYK
# 1   Jordan Adams  SG  20  MEM
# 2   Steven Adams   C  21  OKC
# 3    Jeff Adrien  PF  28  MIN
# 4  Arron Afflalo  SG  29  TOT

# %%
hh1.columns   #list all columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
hh2.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm'], dtype='object')

# %%
ur="https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/fa71405126017e6a37bea592440b4bee94bf7b9e/titanic.csv"
#titanic dataset
#all web data set can be read in pandas
# i saved link in a variable  'ur'
nc=pd.read_csv(ur)
nc
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
# select few columns
nc1=nc[['Name','Age','Pclass']]
nc11=nc[['Name','Age','Pclass']].head()
nc[['Name','Age','Pclass']].head()
# or show  nc11
# Out:
#                                                 Name   Age  Pclass
# 0                            Braund, Mr. Owen Harris  22.0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0       1
# 2                             Heikkinen, Miss. Laina  26.0       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0       1
# 4                           Allen, Mr. William Henry  35.0       3

# %%
#nrows
nc2=pd.read_csv(ur,nrows=10)   # nrows=10   so it reads only 10 rows while reading.
nc2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
nc2.head()  # we can also use head()  to that 10 columns
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#info()   shows  the details and datatypes and its counts also
# in output-  Age has 714   out of 891  rows     so i shows others are blank values  or NaN
nc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB
