# %% [markdown]
# # Pandas - Assignment 3

# %% [raw]
#  Datasets
# 1. https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv
#
# 2. https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv
#
# 1. Get the Metadata from the above files.
#
# 2. Get the row names from the above files.
#
# 3. Change the column name from any of the above file and store the changes made permanently.
#
# 4. Change the names of multiple columns.
#
# 5. Arrange values of a particular column in ascending order.
#
# 6. Arrange multiple column values in ascending order.
#
# 7. Make country as the first column of the dataframe.
#
# 8. Get the column array using a variable
#
# 9. Get the subset rows 11, 24, 37
#
# 10. Get the subset rows excluding 5, 12, 23, and 56
#
# 11.find rows with NaN values
#
# 12. show rows from dataset 1 country = india with high income

# %%
import pandas as pd

# %%
d1=r"https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv"
d2=r"https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv"

# %%
df1=pd.read_csv(d1)
# df1
df1.head()
# Out:
#                            Indicator PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
df2=pd.read_csv(d2)
# df2
df2.head()
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
#
#    TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 2    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 3    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 4   -22 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
# 2 -9999 -9999
# ...

# %%
#1. Get the Metadata from the above files.

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %%
#2. Get the row names from the above files.

df1.index
# Out:
# RangeIndex(start=0, stop=4656, step=1)

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=117208, step=1)

# %%
#3. Change the column name from any of the above file and store the changes made permanently.

df1.head(1)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
#
#    High  Comments
# 0   NaN       NaN

# %%
df1.rename(columns={'Country':'Nation'},inplace=True)
df1.head(1)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
#
#   World Bank income group   Nation         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
#
#    High  Comments
# 0   NaN       NaN

# %%
df2.head(1)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
#
#    TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
#
# [1 rows x 21 columns]

# %%
df2.rename(columns={'STATION':'STATION_NO'},inplace=True)
df2.head(1)
# Out:
#           STATION_NO         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
#
#    TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
#
# [1 rows x 21 columns]

# %%
#4. Change the names of multiple columns.
df1.rename(columns={'Indicator':'INDICATOR','Year':'YEAR'}).head(1)
# Out:
#                           INDICATOR PUBLISH STATES  YEAR WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
#
#   World Bank income group   Nation         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
#
#    High  Comments
# 0   NaN       NaN

# %%
df2.rename(columns={'STATION_NAME':'Station_Name','DATE':'Date'}).head(1)
# Out:
#           STATION_NO         Station_Name      Date  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
#
#    TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
#
# [1 rows x 21 columns]

# %%
# 5. Arrange values of a particular column in ascending order.

df1.sort_values('Nation').head()
# Out:
#                                             Indicator PUBLISH STATES  Year  \
# 2245  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 2959                Life expectancy at age 60 (years)      Published  1990
# 1396                Life expectancy at age 60 (years)      Published  2000
# 1395                Life expectancy at age 60 (years)      Published  1990
# 1394                 Life expectancy at birth (years)      Published  2012
#
#                  WHO region World Bank income group       Nation         Sex  \
# 2245  Eastern Mediterranean              Low-income  Afghanistan  Both sexes
# 2959  Eastern Mediterranean              Low-income  Afghanistan        Male
# 1396  Eastern Mediterranean              Low-income  Afghanistan  Both sexes
# 1395  Eastern Mediterranean              Low-income  Afghanistan  Both sexes
# 1394  Eastern Mediterranean              Low-income  Afghanistan      Female
#
#       Display Value  Numeric  Low  High  Comments
# ...

# %%
df2.sort_values('PRCP',ascending=False).head()
# Out:
#                STATION_NO         STATION_NAME      DATE  PRCP  SNWD  SNOW  \
# 40441   GHCND:GM000003319     BERLIN DAHLEM GM  19480814  1247 -9999 -9999
# 15057   GHCND:GME00111445  BERLIN TEMPELHOF GM  19780808  1195     0 -9999
# 103655  GHCND:GME00121150      BERLIN TEGEL GM  19780808  1064     0 -9999
# 51392   GHCND:GM000003319     BERLIN DAHLEM GM  19780808  1060 -9999 -9999
# 87917   GHCND:GM000003342           POTSDAM GM  19780808  1048 -9999 -9999
#
#         TMAX  TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  \
# 40441    210   125 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 15057    185   144 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 103655   185   149 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 51392    180   144 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 87917    201   141 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#         WT08  WT18  WT03
# ...

# %%
#6. Arrange multiple column values in ascending order.

df1.sort_values(['Nation','Year','Sex']).head()
# Out:
#                               Indicator PUBLISH STATES  Year  \
# 554    Life expectancy at birth (years)      Published  1990
# 1395  Life expectancy at age 60 (years)      Published  1990
# 555   Life expectancy at age 60 (years)      Published  1990
# 1792   Life expectancy at birth (years)      Published  1990
# 965    Life expectancy at birth (years)      Published  1990
#
#                  WHO region World Bank income group       Nation         Sex  \
# 554   Eastern Mediterranean              Low-income  Afghanistan  Both sexes
# 1395  Eastern Mediterranean              Low-income  Afghanistan  Both sexes
# 555   Eastern Mediterranean              Low-income  Afghanistan      Female
# 1792  Eastern Mediterranean              Low-income  Afghanistan      Female
# 965   Eastern Mediterranean              Low-income  Afghanistan        Male
#
#       Display Value  Numeric  Low  High  Comments
# 554              49     49.0  NaN   NaN       NaN
# ...

# %%
df2.sort_values(['PRCP','TMAX','TMIN']).head()
# Out:
#               STATION_NO         STATION_NAME      DATE  PRCP  SNWD  SNOW  \
# 96548  GHCND:GME00121150      BERLIN TEGEL GM  19400119 -9999 -9999 -9999
# 3202   GHCND:GME00111445  BERLIN TEMPELHOF GM  19400217 -9999 -9999 -9999
# 96540  GHCND:GME00121150      BERLIN TEGEL GM  19400110 -9999 -9999 -9999
# 97270  GHCND:GME00121150      BERLIN TEGEL GM  19420122 -9999 -9999 -9999
# 97271  GHCND:GME00121150      BERLIN TEGEL GM  19420123 -9999 -9999 -9999
#
#        TMAX  TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  \
# 96548 -9999  -222 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 3202  -9999  -211 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 96540 -9999  -200 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 97270 -9999  -200 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 97271 -9999  -200 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#        WT08  WT18  WT03
# 96548 -9999 -9999 -9999
# ...

# %%
#7. Make country as the first column of the dataframe.
df11=df1.rename(columns={'Nation':'Country'})
df11.set_index('Country').head()
# Out:
#                                               Indicator PUBLISH STATES  Year  \
# Country
# Andorra                Life expectancy at birth (years)      Published  1990
# Andorra                Life expectancy at birth (years)      Published  2000
# Andorra               Life expectancy at age 60 (years)      Published  2012
# Andorra               Life expectancy at age 60 (years)      Published  2000
# United Arab Emirates   Life expectancy at birth (years)      Published  2012
#
#                                  WHO region World Bank income group  \
# Country
# Andorra                              Europe             High-income
# Andorra                              Europe             High-income
# Andorra                              Europe             High-income
# Andorra                              Europe             High-income
# United Arab Emirates  Eastern Mediterranean             High-income
#
# ...

# %%
# 8. Get the column array using a variable

a=df1.columns
a
# Out:
# Index(['Indicator', 'PUBLISH STATES', 'Year', 'WHO region',
#        'World Bank income group', 'Nation', 'Sex', 'Display Value', 'Numeric',
#        'Low', 'High', 'Comments'],
#       dtype='object')

# %%
b=df2.columns
b
# Out:
# Index(['STATION_NO', 'STATION_NAME', 'DATE', 'PRCP', 'SNWD', 'SNOW', 'TMAX',
#        'TMIN', 'WDFG', 'PGTM', 'WSFG', 'WT09', 'WT07', 'WT01', 'WT06', 'WT05',
#        'WT04', 'WT16', 'WT08', 'WT18', 'WT03'],
#       dtype='object')

# %%
#9. Get the subset rows 11, 24, 37

df1.iloc[[11,24,37]]
# Out:
#                             Indicator PUBLISH STATES  Year       WHO region  \
# 11   Life expectancy at birth (years)      Published  2012           Europe
# 24  Life expectancy at age 60 (years)      Published  2012  Western Pacific
# 37  Life expectancy at age 60 (years)      Published  2012           Europe
#
#    World Bank income group             Nation     Sex  Display Value  Numeric  \
# 11             High-income            Austria  Female             83     83.0
# 24             High-income  Brunei Darussalam  Female             21     21.0
# 37             High-income             Cyprus  Female             26     26.0
#
#     Low  High  Comments
# 11  NaN   NaN       NaN
# 24  NaN   NaN       NaN
# 37  NaN   NaN       NaN

# %%
df2.iloc[[11,24,37]]
# Out:
#            STATION_NO         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 11  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310114    15 -9999 -9999     0
# 24  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310129    56 -9999 -9999    11
# 37  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310212   930 -9999 -9999    61
#
#     TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 11   -22 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 24   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 37 -9999 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#     WT18  WT03
# 11 -9999 -9999
# 24 -9999 -9999
# 37 -9999 -9999
#
# [3 rows x 21 columns]

# %%
# 10. Get the subset rows excluding 5, 12, 23, and 56

df1.drop([5,12,23,56]).head(55)
# Out:
#                             Indicator PUBLISH STATES  Year  \
# 0    Life expectancy at birth (years)      Published  1990
# 1    Life expectancy at birth (years)      Published  2000
# 2   Life expectancy at age 60 (years)      Published  2012
# 3   Life expectancy at age 60 (years)      Published  2000
# 4    Life expectancy at birth (years)      Published  2012
# 6   Life expectancy at age 60 (years)      Published  1990
# 7   Life expectancy at age 60 (years)      Published  2012
# 8    Life expectancy at birth (years)      Published  2012
# 9    Life expectancy at birth (years)      Published  2000
# 10   Life expectancy at birth (years)      Published  2012
# 11   Life expectancy at birth (years)      Published  2012
# 13   Life expectancy at birth (years)      Published  2012
# 14   Life expectancy at birth (years)      Published  2000
# 15   Life expectancy at birth (years)      Published  1990
# 16  Life expectancy at age 60 (years)      Published  1990
# ...

# %%
df2.drop([5,12,23,56]).head(55)
# Out:
#            STATION_NO         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
# 6   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310108    13 -9999 -9999    11
# 7   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310109    10 -9999 -9999   -22
# 8   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310110 -9999 -9999 -9999     0
# 9   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310112 -9999 -9999 -9999    22
# 10  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310113    13 -9999 -9999     0
# 11  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310114    15 -9999 -9999     0
# ...

# %%
# 11.find rows with NaN values

df1[df1.isnull().any(1)]
# df1.isnull().any(1)
# Out:
#                                             Indicator PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# 5                    Life expectancy at birth (years)      Published  2000
# 6                   Life expectancy at age 60 (years)      Published  1990
# 7                   Life expectancy at age 60 (years)      Published  2012
# 8                    Life expectancy at birth (years)      Published  2012
# 9                    Life expectancy at birth (years)      Published  2000
# 10                   Life expectancy at birth (years)      Published  2012
# ...

# %%
df2[df2.isnull().any(1)]
# df2.isnull().any(1)
# Out:
# Empty DataFrame
# Columns: [STATION_NO, STATION_NAME, DATE, PRCP, SNWD, SNOW, TMAX, TMIN, WDFG, PGTM, WSFG, WT09, WT07, WT01, WT06, WT05, WT04, WT16, WT08, WT18, WT03]
# Index: []
#
# [0 rows x 21 columns]

# %%
# 12. show rows from dataset 1 country = india with high income

df12=df11[df11['Country']=='India']
df12
# Out:
#                                             Indicator PUBLISH STATES  Year  \
# 372                  Life expectancy at birth (years)      Published  2012
# 373                  Life expectancy at birth (years)      Published  2012
# 750                  Life expectancy at birth (years)      Published  2000
# 751                  Life expectancy at birth (years)      Published  1990
# 752                 Life expectancy at age 60 (years)      Published  2000
# 753                 Life expectancy at age 60 (years)      Published  2012
# 754                 Life expectancy at age 60 (years)      Published  2012
# 1152                 Life expectancy at birth (years)      Published  2000
# 1153                 Life expectancy at birth (years)      Published  2012
# 1154                 Life expectancy at birth (years)      Published  2000
# 1155                Life expectancy at age 60 (years)      Published  2000
# ...

# %%
# df12[df12['World Bank income group']=='Lower-middle-income']
df12[df12['World Bank income group']=='High-income']
# Out:
# Empty DataFrame
# Columns: [Indicator, PUBLISH STATES, Year, WHO region, World Bank income group, Country, Sex, Display Value, Numeric, Low, High, Comments]
# Index: []
